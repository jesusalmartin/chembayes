# %%
from chembayes import optimize_experiment
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from chembayes import optimize_experiment
#       2 import pandas as pd
#
# ModuleNotFoundError: No module named 'chembayes'

# %%
df = pd.read_csv('data/test_data.csv')

# %%
inputs = [
    'mL_HNO3',
    'EtOH/H2O',
    'Tiempo (h)',
]

outputs = {
    'S_BET_lavado': 0.75,
    'm_HKUST-1_lavado (g) ': 0.25
}

# %%
result = optimize_experiment(df=df, inputs=inputs, output='S_BET_lavado', plot=True)
# Out:
# [I 2026-04-24 12:38:00,298] A new study created in memory with name: no-name-6fb9363e-aba1-4a84-be4d-077073780769
# [I 2026-04-24 12:38:00,313] Trial 0 finished with value: 8.81873892998172 and parameters: {'length_scale': 0.8079137033676459, 'noise_level': 0.0010659891890359287, 'nu_idx': 3}. Best is trial 0 with value: 8.81873892998172.
# [I 2026-04-24 12:38:00,329] Trial 1 finished with value: 9.167910234055299 and parameters: {'length_scale': 1.1641268415880783, 'noise_level': 0.005216779184933368, 'nu_idx': 3}. Best is trial 0 with value: 8.81873892998172.
# [I 2026-04-24 12:38:00,346] Trial 2 finished with value: 7.952805771707357 and parameters: {'length_scale': 0.43906637619994004, 'noise_level': 0.5616714416734747, 'nu_idx': 3}. Best is trial 2 with value: 7.952805771707357.
# ...
