# %%
from chembayes import optimize_experiment
import pandas as pd

# %%
# Example data loading
df = pd.read_csv('data/test_data.csv')

# %%
# Inputs selection
inputs = [
    'x1_num_std_normal',
    'x2_num_uniform_m50_50',
    'x3_num_lognormal',
    'x4_num_exponential',
    'x5_num_shifted_normal',
    'c1_cat_ABC',
    'c2_cat_XY',
    'c3_cat_colors'
]

# %%
# Single output optimization
single_opt_result = optimize_experiment(df=df, inputs=inputs, output='y1', plot=True)
# Out:
# [I 2026-04-29 12:20:07,693] A new study created in memory with name: no-name-109f3f24-d48d-4313-8870-259fb21f9421
# [I 2026-04-29 12:20:07,999] Trial 0 finished with value: 1.386923769450871 and parameters: {'length_scale': 8.281835397765414, 'noise_level': 0.12360890641279883, 'nu_idx': 1}. Best is trial 0 with value: 1.386923769450871.
# [I 2026-04-29 12:20:08,402] Trial 1 finished with value: 1.6050784166192593 and parameters: {'length_scale': 1.9434090124922025, 'noise_level': 0.06798327767543569, 'nu_idx': 1}. Best is trial 0 with value: 1.386923769450871.
# [I 2026-04-29 12:20:08,683] Trial 2 finished with value: 6.005920867467178 and parameters: {'length_scale': 9.584985637144767, 'noise_level': 0.002623389235159162, 'nu_idx': 1}. Best is trial 0 with value: 1.386923769450871.
# ...

# %%
# Weighted outputs optimization
outputs = {
    'y1': 0.75,
    'y2': 0.5,
    'y3': 0.25
}

weighted_opt_result = optimize_experiment(df=df, inputs=inputs, output=outputs, plot=True)
# Out:
# [I 2026-04-29 12:20:45,514] A new study created in memory with name: no-name-be3a4571-0364-457e-b48d-93936c2a9ea7
# [I 2026-04-29 12:20:45,805] Trial 0 finished with value: 7.934096170282528 and parameters: {'length_scale': 8.914881113882274, 'noise_level': 0.0016612546211779856, 'nu_idx': 2}. Best is trial 0 with value: 7.934096170282528.
# [I 2026-04-29 12:20:46,090] Trial 1 finished with value: 1.7526620617328093 and parameters: {'length_scale': 0.41666360278488623, 'noise_level': 0.289765070339373, 'nu_idx': 0}. Best is trial 1 with value: 1.7526620617328093.
# [I 2026-04-29 12:20:46,352] Trial 2 finished with value: 1.7820944747838283 and parameters: {'length_scale': 0.20431557172501652, 'noise_level': 0.3058707680132151, 'nu_idx': 0}. Best is trial 1 with value: 1.7526620617328093.
# ...
